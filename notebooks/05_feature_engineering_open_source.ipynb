# %% [markdown]
# # 05 Feature Engineering Open Source
#
# Creates unsupervised/open-source-only features such as calendar, lag, and rolling-window signals. Supervised feature selection and feature importance are Databricks-only because they require target data.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = Path.cwd().parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import RESTRICTED_DATA_WARNING
print(RESTRICTED_DATA_WARNING)

# %%
from src import paths
from src.open_source_feature_engineering import engineer_all_features

feature_manifest = engineer_all_features(paths.cleaned_dir(), paths.feature_dir())
feature_manifest
