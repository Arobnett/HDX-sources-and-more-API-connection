# %% [markdown]
# # 01 Collect Open Source Data
#
# This notebook is the collection checkpoint. It should only stage public/open-source outputs. Existing source-specific collection code can write country-month-year CSVs into `outputs/silver_country_month_year/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = Path.cwd().parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import RESTRICTED_DATA_WARNING
print(RESTRICTED_DATA_WARNING)

# %%
from src import paths
from src.open_source_collection import build_file_inventory, list_silver_files

paths.ensure_output_dirs()
silver_files = list_silver_files(paths.silver_dir())
print(f'Silver files discovered: {len(silver_files)}')
for path in silver_files[:10]:
    print(path.name)

inventory = build_file_inventory(paths.silver_dir(), paths.manifest_dir() / 'silver_file_inventory.csv')
inventory
