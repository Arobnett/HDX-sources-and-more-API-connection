# %% [markdown]
# # 03 Clean And Preprocess Open Source
#
# Performs open-source-only cleaning checks after standardization, including missingness summaries. It does not join to any target data.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = Path.cwd().parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import RESTRICTED_DATA_WARNING
print(RESTRICTED_DATA_WARNING)

# %%
from src import paths
from src.open_source_cleaning import build_missingness_report

missingness = build_missingness_report(paths.cleaned_dir(), paths.eda_dir() / 'missingness_report.csv')
missingness.sort_values(['missing_rate', 'missing_rows'], ascending=False).head(25)
