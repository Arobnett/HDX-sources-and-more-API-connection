# %% [markdown]
# # 02 Standardize Country Month Year
#
# Standardizes country/post/year/month fields for public source outputs only. Post-based country standardization uses the deduplicated `reference/post_mission_region_lookup.csv`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = Path.cwd().parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import RESTRICTED_DATA_WARNING
print(RESTRICTED_DATA_WARNING)

# %%
from src import paths
from src.open_source_cleaning import clean_all_open_source_files

paths.ensure_output_dirs()
manifest = clean_all_open_source_files(paths.silver_dir(), paths.cleaned_dir(), paths.post_lookup_path())
manifest
