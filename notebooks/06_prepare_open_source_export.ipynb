# %% [markdown]
# # 06 Prepare Open Source Export
#
# Creates an open-source-only export folder for later enterprise Databricks ingestion. The exported files are still features only and contain no target joins.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = Path.cwd().parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import RESTRICTED_DATA_WARNING
print(RESTRICTED_DATA_WARNING)

# %%
from src import paths
from src.export_for_databricks import export_feature_files

export_manifest = export_feature_files(paths.feature_dir(), paths.export_dir())
export_manifest
